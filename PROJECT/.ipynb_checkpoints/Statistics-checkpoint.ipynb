# %% [markdown]
# ## 4. Statistical Analysis
# In this analysis, we aim to investigate the relationship between certain features (mean sentiment, standard deviation of sentiment, and volume of articles) and the daily returns of the Novo Nordisk stock. Specifically, we want to determine if these features can predict whether the stock's daily return is positive or negative. To achieve this, we employ two statistical methods: Logistic Regression and Ordinary Least Squares (OLS) Regression.

# %% [markdown]
# #### 4.1 Importing packages and DataFrame

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.discrete.discrete_model import Logit

## Importing the clean data frame from the Data_merging file
df_final = pd.read_csv('./CSV/df_merged_clean.csv')

#Print to ensure it is the right data frame
df_final
# Out:
#             Date  mean_sentiment  std_sentiment  daily_volume  daily_return
# 0     2001-01-09        2.500000       3.535534             2      0.000000
# 1     2001-01-15       -0.500000       0.707107             2      0.000000
# 2     2001-01-19       -0.333333       0.577350             3      0.000000
# 3     2001-01-25        0.000000       0.000000             2      0.000000
# 4     2001-01-26        0.400000       0.894427             5      0.000000
# ...          ...             ...            ...           ...           ...
# 2062  2023-08-07        0.000000       0.000000             3      0.028071
# 2063  2023-08-08        0.250000       2.179449            12      0.172622
# 2064  2023-08-09        1.444444       2.962731             9     -0.012815
# 2065  2023-08-10       -0.400000       1.776388            10     -0.012189
# 2066  2023-08-11       -2.000000       2.828427             2     -0.005449
#
# [2067 rows x 5 columns]

# %% [markdown]
# #### 4.2 Performing the regressions
# We begin by identifying the variables intended for our regression analysis. Although we experimented with an interaction term between the average sentiment and the volume of articles, it altered the significance of the average sentiment. We opted to omit this interaction term to maintain consistency with our broader analysis, which is elaborated upon in greater detail within the project.

# %%
# Creating a DataFrame 'xs' containing the features
xs = df_final[['mean_sentiment', 'std_sentiment', 'daily_volume']]

# Create the interaction term 
# xs['mean_volume_interaction'] = xs['mean'] * xs['volume']

# Convert 'daily_return' to binary (1 if positive, 0 if negative)
df_final['return_category'] = df_final['daily_return'].apply(lambda x: 1 if x > 0 else 0)
ys = df_final[['return_category']]
y = df_final[['daily_return']]

# Adding a constant term to the features DataFrame
xs = sm.add_constant(xs)

# %% [markdown]
# Initially, we employ a logistic regression given that we're examining $y$ as a binary outcome, where $y \in \{0,1\}$. Subsequently, we conduct a standard OLS regression, treating $y$ as a continuous variable.

# %%
# Setting up the logistic regression
logit_mod = Logit(ys, xs)
logit_res = logit_mod.fit(maxiter=200)
print(logit_res.summary().as_latex())

# If you also want to run an OLS regression:
OLS_mod = sm.OLS(y, xs)
OLS_res = OLS_mod.fit()
print(OLS_res.summary().as_latex())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.684265
#          Iterations 4
# \begin{center}
# \begin{tabular}{lclc}
# \toprule
# \textbf{Dep. Variable:}   & return\_category & \textbf{  No. Observations:  } &     2067    \\
# \textbf{Model:}           &      Logit       & \textbf{  Df Residuals:      } &     2063    \\
# \textbf{Method:}          &       MLE        & \textbf{  Df Model:          } &        3    \\
# \textbf{Date:}            & Wed, 16 Aug 2023 & \textbf{  Pseudo R-squ.:     } &  0.01045    \\
# \textbf{Time:}            &     16:43:12     & \textbf{  Log-Likelihood:    } &   -1414.4   \\
# \textbf{converged:}       &       True       & \textbf{  LL-Null:           } &   -1429.3   \\
# \textbf{Covariance Type:} &    nonrobust     & \textbf{  LLR p-value:       } & 1.473e-06   \\
# \bottomrule
# \end{tabular}
# \begin{tabular}{lcccccc}
#                          & \textbf{coef} & \textbf{std err} & \textbf{z} & \textbf{P$> |$z$|$} & \textbf{[0.025} & \textbf{0.975]}  \\
# \midrule
# \textbf{const}           &       0.1094  &        0.081     &     1.347  &         0.178        &       -0.050    &        0.269     \\
# \textbf{mean\_sentiment} &       0.2790  &        0.053     &     5.239  &         0.000        &        0.175    &        0.383     \\
# \textbf{std\_sentiment}  &       0.0176  &        0.054     &     0.327  &         0.744        &       -0.088    &        0.123     \\
# \textbf{daily\_volume}   &      -0.0105  &        0.012     &    -0.868  &         0.386        &       -0.034    &        0.013     \\
# \bottomrule
# \end{tabular}
# %\caption{Logit Regression Results}
# \end{center}
# \begin{center}
# \begin{tabular}{lclc}
# \toprule
# \textbf{Dep. Variable:}    &  daily\_return   & \textbf{  R-squared:         } &     0.021   \\
# \textbf{Model:}            &       OLS        & \textbf{  Adj. R-squared:    } &     0.020   \\
# \textbf{Method:}           &  Least Squares   & \textbf{  F-statistic:       } &     14.92   \\
# \textbf{Date:}             & Wed, 16 Aug 2023 & \textbf{  Prob (F-statistic):} &  1.30e-09   \\
# \textbf{Time:}             &     16:43:12     & \textbf{  Log-Likelihood:    } &    4912.8   \\
# \textbf{No. Observations:} &        2067      & \textbf{  AIC:               } &    -9818.   \\
# \textbf{Df Residuals:}     &        2063      & \textbf{  BIC:               } &    -9795.   \\
# \textbf{Df Model:}         &           3      & \textbf{                     } &             \\
# \textbf{Covariance Type:}  &    nonrobust     & \textbf{                     } &             \\
# \bottomrule
# \end{tabular}
# \begin{tabular}{lcccccc}
#                          & \textbf{coef} & \textbf{std err} & \textbf{t} & \textbf{P$> |$t$|$} & \textbf{[0.025} & \textbf{0.975]}  \\
# \midrule
# \textbf{const}           &       0.0021  &        0.001     &     2.286  &         0.022        &        0.000    &        0.004     \\
# \textbf{mean\_sentiment} &       0.0032  &        0.001     &     5.604  &         0.000        &        0.002    &        0.004     \\
# \textbf{std\_sentiment}  &       0.0011  &        0.001     &     1.843  &         0.065        &    -7.03e-05    &        0.002     \\
# \textbf{daily\_volume}   &      -0.0004  &        0.000     &    -2.995  &         0.003        &       -0.001    &       -0.000     \\
# \bottomrule
# \end{tabular}
# \begin{tabular}{lclc}
# \textbf{Omnibus:}       & 561.035 & \textbf{  Durbin-Watson:     } &     2.130  \\
# \textbf{Prob(Omnibus):} &   0.000 & \textbf{  Jarque-Bera (JB):  } & 24900.028  \\
# \textbf{Skew:}          &   0.496 & \textbf{  Prob(JB):          } &      0.00  \\
# \textbf{Kurtosis:}      &  19.974 & \textbf{  Cond. No.          } &      11.8  \\
# \bottomrule
# \end{tabular}
# %\caption{OLS Regression Results}
# \end{center}
#
# Notes: \newline
#  [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# #### 4.3 Logistic Regression Curve
# We want to visualize the relationship between the single independent variable, mean sentiment, and the binary outcome $y \in \{0,1\}$, as the mean sentiment is the only significant feature.

# %%
# We only plot the curve using 'mean', as this proves to be the only variable with significant effect. 
x = df_final['mean_sentiment']
#sns.regplot(y = ys, x = x, data = df_final, logistic = True)

# Plotting the logistic regression curve
plt.figure(figsize=(10, 6))  # Set the figure size
sns.regplot(y = ys, x = x, data = df_final, logistic=True, scatter_kws={'s':10, 'alpha':0.3}, line_kws={'color':'blue'})

# Adding title and labels
plt.title('Logistic Regression: Mean Sentiment vs. Return Category', fontsize=16, fontweight='bold', fontname='DejaVu Sans')
plt.xlabel('Mean Sentiment', fontsize=12, fontname='DejaVu Sans')
plt.ylabel('Probability of Positive Return', fontsize=12, fontname='DejaVu Sans')
plt.tight_layout()

plt.savefig('Logistic_Regression_Curve.png')
plt.show()
