# %% [markdown]
# ## Scraping Børsen for articles about Novo Nordisk

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from webdriver_manager.chrome import ChromeDriverManager
from selenium.common.exceptions import NoSuchElementException
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
from afinn import Afinn

import matplotlib.pyplot as plt
import time
import requests
import os
from bs4 import BeautifulSoup
import pandas as pd
import re
import datetime
import nltk

# %%
# Set up Selenium with Chrome driver
driver = webdriver.Chrome()
driver.maximize_window()

# Specify the URL
url = "https://borsen.dk/"
driver.get(url)
time.sleep(0.5)

# Accept cookies
cookie = driver.find_element(By.ID, 'acceptButton')
cookie.click()
time.sleep(0.5)

# Click on the search button
search_button = driver.find_element(By.CLASS_NAME, 'icon-search')
search_button.click()
time.sleep(2)

# Search for "Novo Nordisk"
search_input = driver.find_element(By.XPATH, '//input[@type="text"]')
search_input.send_keys('Novo Nordisk')
search_input.send_keys(Keys.RETURN)

# %%
titles = []
dates = []

while True:
    # Use Beautiful Soup to parse the current page's HTML
    soup = BeautifulSoup(driver.page_source, "html.parser")

    # Find all titles and dates with the specified class
    title_divs = soup.find_all('div', class_='title mb-3')
    date_divs = soup.find_all('div', class_='gta-condensed date')

    for title_div, date_div in zip(title_divs, date_divs):
        titles.append(title_div.text.strip())
        dates.append(date_div.text.strip())

    # Try to find the "Next" button/link and click it to go to the next page
    try:
        next_button = driver.find_element(By.CSS_SELECTOR, ".col-3.next a")
        next_button.click()
        time.sleep(2)
    except NoSuchElementException:
        break

# Convert the lists to a pandas DataFrame
df = pd.DataFrame({
    'Title': titles,
    'Date': dates
})

df
# Out:
#                                                    Title           Date
# 0      Danskere på rov: Køber virksomheder i udlandet...       12. AUG.
# 1      Ugen der gik: Våbenbøvl, millionunderskud og N...       12. AUG.
# 2      Chefstrateg solgte medicinalaktie alt for hurt...       11. AUG.
# 3      C25 i stort fald: Her er aktierne, der rykkede...       11. AUG.
# 4            Novo-insidere sælger aktier for 29 mio. kr.       11. AUG.
# ...                                                  ...            ...
# 26830                                   Centerkontrakter  28. JUN. 1996
# 26831                           Fremgang for Micro Matic  27. JUN. 1996
# 26832                         Øser af sin miljø-erfaring  26. JUN. 1996
# 26833       Danske virksomheder tvinges til nedskæringer  24. JUN. 1996
# 26834                     Vores Øl bliver til Vores Cola  21. JUN. 1996
#
# [26835 rows x 2 columns]

# %%
#To filter the articles, we make a list of keywords
#Initially, this list must inclide the names of all Novo Nordisk medical products. These can be obtained as follows: 

# URL to scrape from
url = "https://min.medicin.dk/Adresser/Medicinvirksomheder/126/"

# Send a GET request
response = requests.get(url, headers={'name': 'Rosemarie Blicher', 'e-mail':'mzc44@alumni.ku.dk', 'purpose':'University of Copenhagen Social Data Science exam project'})

# Parse the content with BeautifulSoup
soup = BeautifulSoup(response.content, 'lxml')

# Find all product elements
product_elements = soup.find_all('a', class_='glob-search_link')

# Extract the product names from the title attribute
product_names = [product['title'] for product in product_elements]

# Removing special characters and numbers from each product name by using Regular Expressions
product_names_cleaned = [re.sub(r'[^a-zA-Z\s]', '', name) for name in product_names]

# For the 28th element, split it into 2 by space
words = product_names_cleaned[28].split()

# Replace the 28th name with the first word
product_names_cleaned[28] = words[0]

# Insert the second word as the 29th element
product_names_cleaned.insert(30, words[1])

#Print the list
product_names_cleaned
# Out:
# ['Activelle',
#  'Actrapid',
#  'Esperoct',
#  'Estrofem',
#  'Fiasp',
#  'GlucaGen',
#  'Insulatard',
#  'Kliogest',
#  'Levemir',
#  'Mixtard ',
#  'Norditropin',
#  'NovoEight',
#  'Novofem',
#  'NovoMix',
#  'NovoNorm',
#  'NovoRapid',
#  'Novoseven',
#  'NovoThirteen',
#  'Ozempic',
#  'Refixia',
#  'Rybelsus',
#  'Ryzodeg',
#  'Saxenda',
#  'Sogroya',
#  'Tresiba',
#  'Trisekvens',
#  'Vagifem',
#  'Victoza',
#  'Wegovy',
#  'Xultophy',
#  'Flextouch']

# %%
# Define additional keywords, these are determined manually by research on Novo Nordisk medical expertise
keywords = ["Novo", "Nordisk", "insulin", "fedme", "diabetes", "vægttab", "præparat", "overvægt", "slank", "medicin", "pille"]

# We then append the product_names_cleaned list to the keywords list
for product in product_names_cleaned:
    keywords.append(product)

print(keywords)
# Out:
# ['Novo', 'Nordisk', 'insulin', 'fedme', 'diabetes', 'vægttab', 'præparat', 'overvægt', 'slank', 'medicin', 'pille', 'Activelle', 'Actrapid', 'Esperoct', 'Estrofem', 'Fiasp', 'GlucaGen', 'Insulatard', 'Kliogest', 'Levemir', 'Mixtard ', 'Norditropin', 'NovoEight', 'Novofem', 'NovoMix', 'NovoNorm', 'NovoRapid', 'Novoseven', 'NovoThirteen', 'Ozempic', 'Refixia', 'Rybelsus', 'Ryzodeg', 'Saxenda', 'Sogroya', 'Tresiba', 'Trisekvens', 'Vagifem', 'Victoza', 'Wegovy', 'Xultophy', 'Flextouch']

# %%
# Convert the keywords to lowercase for case-insensitive matching
keywords_lower = [word.lower() for word in keywords]

# Filter the dataframe based on the condition
df_filtered = df[df['Title'].str.lower().str.contains('|'.join(keywords_lower))]

#Reset index
df_filtered = df_filtered.reset_index(drop=True)


dict_en = {'JAN': 'JAN', 'FEB': 'FEB', 'MAR': 'MAR', 'APR': 'APR', 'MAJ': 'MAY', 'JUN': 'JUN', 'JUL': 'JUL', 'AUG': 'AUG', 'SEP': 'SEP', 'OKT': 'OCT', 'NOV': 'NOV', 'DEC': 'DEC'}

def convert_date(date_string):
    # Remove periods
    date_string = date_string.replace('.', '').strip()

    # Translate month names to English
    for danish, english in dict_en.items():
        date_string = date_string.replace(danish, english)

    # Handle different date formats
    if ":" in date_string:  # It's a time
        return datetime.datetime.now().strftime('%Y-%m-%d')  # Return today's date
    elif len(date_string.split()) == 2:  # Day and month
        current_year = datetime.datetime.now().year
        return datetime.datetime.strptime(date_string + f" {current_year}", '%d %b %Y').strftime('%Y-%m-%d')
    else:  # Full date
        return datetime.datetime.strptime(date_string, '%d %b %Y').strftime('%Y-%m-%d')

# Apply the conversion function to the 'Date' column
df_filtered['Date'] = df_filtered['Date'].apply(convert_date)
df_filtered
# Out:
#                                                   Title        Date
# 0     Ugen der gik: Våbenbøvl, millionunderskud og N...  2023-08-12
# 1     Chefstrateg solgte medicinalaktie alt for hurt...  2023-08-11
# 2           Novo-insidere sælger aktier for 29 mio. kr.  2023-08-11
# 3     Novos udviklingschef efter vild uge: Flere suc...  2023-08-10
# 4     Et nationalregnskab uden Novo Nordisk? Ikke nø...  2023-08-10
# ...                                                 ...         ...
# 7948                     Novo på vej mod rekordresultat  1996-08-15
# 7949                      Novo trak KFX frem til rekord  1996-08-15
# 7950                     Novo-resultat bliver som lovet  1996-08-14
# 7951         Historien om insulin-krigen i Novo Nordisk  1996-07-18
# 7952    Manden der vil ændre insulinets verdenshistorie  1996-07-18
#
# [7953 rows x 2 columns]

# %%
#Now we want to process the text data

#We define a processing function that carries out the wanted steps 
def process_text(cell_text): 
    cell_text=cell_text.lower() #Change to lower case
    cell_text=re.sub(r'[^\w\s]','',cell_text) #Remove all characters that are not words or numbers
    cell_text=cell_text.split() #Split at whitespace with the split() method (i.e., tokenization)
    return cell_text

#We now apply the process function to the titles 
df_filtered['Title'] = df_filtered['Title'].apply(process_text)
df_filtered
# Out:
#                                                   Title        Date
# 0     [ugen, der, gik, våbenbøvl, millionunderskud, ...  2023-08-12
# 1     [chefstrateg, solgte, medicinalaktie, alt, for...  2023-08-11
# 2      [novoinsidere, sælger, aktier, for, 29, mio, kr]  2023-08-11
# 3     [novos, udviklingschef, efter, vild, uge, fler...  2023-08-10
# 4     [et, nationalregnskab, uden, novo, nordisk, ik...  2023-08-10
# ...                                                 ...         ...
# 7948               [novo, på, vej, mod, rekordresultat]  1996-08-15
# 7949               [novo, trak, kfx, frem, til, rekord]  1996-08-15
# 7950                 [novoresultat, bliver, som, lovet]  1996-08-14
# 7951   [historien, om, insulinkrigen, i, novo, nordisk]  1996-07-18
# 7952  [manden, der, vil, ændre, insulinets, verdensh...  1996-07-18
#
# [7953 rows x 2 columns]

# %%
# Convert the 'Date' column to datetime format
df_filtered['Date'] = pd.to_datetime(df_filtered['Date'])

# Filter the dataframe to only include rows from the year 2000 onwards
df_filtered = df_filtered[df_filtered['Date'].dt.year >= 2000]

# Reset the index after filtering
df_filtered = df_filtered.reset_index(drop=True)
df_filtered
# Out:
#                                                   Title       Date
# 0     [ugen, der, gik, våbenbøvl, millionunderskud, ... 2023-08-12
# 1     [chefstrateg, solgte, medicinalaktie, alt, for... 2023-08-11
# 2      [novoinsidere, sælger, aktier, for, 29, mio, kr] 2023-08-11
# 3     [novos, udviklingschef, efter, vild, uge, fler... 2023-08-10
# 4     [et, nationalregnskab, uden, novo, nordisk, ik... 2023-08-10
# ...                                                 ...        ...
# 7609  [læger, sætter, pensionspenge, i, medicinalakt... 2000-01-27
# 7610           [medicinalbranchen, ramt, af, formkrise] 2000-01-20
# 7611        [fremstød, for, dansk, medicin, i, ægypten] 2000-01-19
# 7612   [fusioner, kan, presse, novos, alliancestrategi] 2000-01-18
# 7613        [novos, vinderopskrift, er, interaktivitet] 2000-01-04
#
# [7614 rows x 2 columns]

# %%
#We want to remove stopwords
nltk.download('stopwords')
stop = stopwords.words('danish')

#Remove stopwards
df_filtered['title_nostop'] = df_filtered['Title'].apply(lambda title: [i for i in title if i not in stop])

#We ensure that some stopwords were actually removed
print(len(df_filtered['Title'].iloc[0]), len(df_filtered['title_nostop'].iloc[0]))

#Print the data_frame
df_filtered
# Out:
# 9 6
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/rosemarieblicher/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#                                                   Title       Date  \
# 0     [ugen, der, gik, våbenbøvl, millionunderskud, ... 2023-08-12
# 1     [chefstrateg, solgte, medicinalaktie, alt, for... 2023-08-11
# 2      [novoinsidere, sælger, aktier, for, 29, mio, kr] 2023-08-11
# 3     [novos, udviklingschef, efter, vild, uge, fler... 2023-08-10
# 4     [et, nationalregnskab, uden, novo, nordisk, ik... 2023-08-10
# ...                                                 ...        ...
# 7609  [læger, sætter, pensionspenge, i, medicinalakt... 2000-01-27
# 7610           [medicinalbranchen, ramt, af, formkrise] 2000-01-20
# 7611        [fremstød, for, dansk, medicin, i, ægypten] 2000-01-19
# 7612   [fusioner, kan, presse, novos, alliancestrategi] 2000-01-18
# 7613        [novos, vinderopskrift, er, interaktivitet] 2000-01-04
#
#                                            title_nostop
# 0     [ugen, gik, våbenbøvl, millionunderskud, novoa...
# 1     [chefstrateg, solgte, medicinalaktie, hurtigt,...
# 2           [novoinsidere, sælger, aktier, 29, mio, kr]
# 3     [novos, udviklingschef, vild, uge, flere, succ...
# 4     [nationalregnskab, uden, novo, nordisk, nødven...
# ...                                                 ...
# 7609    [læger, sætter, pensionspenge, medicinalaktier]
# 7610               [medicinalbranchen, ramt, formkrise]
# 7611                [fremstød, dansk, medicin, ægypten]
# 7612   [fusioner, kan, presse, novos, alliancestrategi]
# 7613            [novos, vinderopskrift, interaktivitet]
#
# [7614 rows x 3 columns]

# %%
nltk.download('omw-1.4')
nltk.download('wordnet')

# Initialize the Danish SnowballStemmer
stemmer = SnowballStemmer("danish")

# Define the stemming function
def stem_text(tokens):
    return [stemmer.stem(token) for token in tokens]

# Apply the function to each row of the 'title_nostop' column
df_filtered['title_stemmed'] = df_filtered['title_nostop'].apply(stem_text)

#We check to see of the stemmed words make sense
df_filtered
#From this we conclude that the stemmed danish words are often incorrect. Thus, we continue with determining the sentiment of the nostop column.
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/rosemarieblicher/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/rosemarieblicher/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
#                                                   Title       Date  \
# 0     [ugen, der, gik, våbenbøvl, millionunderskud, ... 2023-08-12
# 1     [chefstrateg, solgte, medicinalaktie, alt, for... 2023-08-11
# 2      [novoinsidere, sælger, aktier, for, 29, mio, kr] 2023-08-11
# 3     [novos, udviklingschef, efter, vild, uge, fler... 2023-08-10
# 4     [et, nationalregnskab, uden, novo, nordisk, ik... 2023-08-10
# ...                                                 ...        ...
# 7609  [læger, sætter, pensionspenge, i, medicinalakt... 2000-01-27
# 7610           [medicinalbranchen, ramt, af, formkrise] 2000-01-20
# 7611        [fremstød, for, dansk, medicin, i, ægypten] 2000-01-19
# 7612   [fusioner, kan, presse, novos, alliancestrategi] 2000-01-18
# 7613        [novos, vinderopskrift, er, interaktivitet] 2000-01-04
#
#                                            title_nostop  \
# 0     [ugen, gik, våbenbøvl, millionunderskud, novoa...
# 1     [chefstrateg, solgte, medicinalaktie, hurtigt,...
# 2           [novoinsidere, sælger, aktier, 29, mio, kr]
# 3     [novos, udviklingschef, vild, uge, flere, succ...
# 4     [nationalregnskab, uden, novo, nordisk, nødven...
# ...                                                 ...
# 7609    [læger, sætter, pensionspenge, medicinalaktier]
# 7610               [medicinalbranchen, ramt, formkrise]
# 7611                [fremstød, dansk, medicin, ægypten]
# 7612   [fusioner, kan, presse, novos, alliancestrategi]
# 7613            [novos, vinderopskrift, interaktivitet]
#
#                                           title_stemmed
# 0     [ugen, gik, våbenbøvl, millionunderskud, novoa...
# 1     [chefstrateg, solg, medicinalakti, hurt, reali...
# 2                  [novoinsid, sælg, akti, 29, mio, kr]
# 3     [novo, udviklingschef, vild, uge, fler, succes...
# 4     [nationalregnskab, uden, novo, nordisk, nødven...
# ...                                                 ...
# 7609            [læg, sæt, pensionspeng, medicinalakti]
# 7610                  [medicinalbranch, ramt, formkris]
# 7611                  [fremstød, dansk, medicin, ægypt]
# 7612        [fusion, kan, pres, novo, alliancestrategi]
# 7613               [novo, vinderopskrift, interaktivit]
#
# [7614 rows x 4 columns]

# %%
#We determne the sentiment using a predefined lexicon
# Initialize the Afinn object for Danish
afn = Afinn(language='da', emoticons=True)

# Convert the list of words in 'title_stemmed' to a single string and then apply the AFINN sentiment scoring function
df_filtered['sentiment_score'] = df_filtered['title_nostop'].apply(lambda title_list: afn.score(' '.join(title_list)))

#Display the Data Frame
df_filtered
# Out:
#                                                   Title       Date  \
# 0     [ugen, der, gik, våbenbøvl, millionunderskud, ... 2023-08-12
# 1     [chefstrateg, solgte, medicinalaktie, alt, for... 2023-08-11
# 2      [novoinsidere, sælger, aktier, for, 29, mio, kr] 2023-08-11
# 3     [novos, udviklingschef, efter, vild, uge, fler... 2023-08-10
# 4     [et, nationalregnskab, uden, novo, nordisk, ik... 2023-08-10
# ...                                                 ...        ...
# 7609  [læger, sætter, pensionspenge, i, medicinalakt... 2000-01-27
# 7610           [medicinalbranchen, ramt, af, formkrise] 2000-01-20
# 7611        [fremstød, for, dansk, medicin, i, ægypten] 2000-01-19
# 7612   [fusioner, kan, presse, novos, alliancestrategi] 2000-01-18
# 7613        [novos, vinderopskrift, er, interaktivitet] 2000-01-04
#
#                                            title_nostop  \
# 0     [ugen, gik, våbenbøvl, millionunderskud, novoa...
# 1     [chefstrateg, solgte, medicinalaktie, hurtigt,...
# 2           [novoinsidere, sælger, aktier, 29, mio, kr]
# 3     [novos, udviklingschef, vild, uge, flere, succ...
# 4     [nationalregnskab, uden, novo, nordisk, nødven...
# ...                                                 ...
# 7609    [læger, sætter, pensionspenge, medicinalaktier]
# 7610               [medicinalbranchen, ramt, formkrise]
# 7611                [fremstød, dansk, medicin, ægypten]
# 7612   [fusioner, kan, presse, novos, alliancestrategi]
# 7613            [novos, vinderopskrift, interaktivitet]
#
#                                           title_stemmed  sentiment_score
# 0     [ugen, gik, våbenbøvl, millionunderskud, novoa...              0.0
# 1     [chefstrateg, solg, medicinalakti, hurt, reali...             -4.0
# 2                  [novoinsid, sælg, akti, 29, mio, kr]              0.0
# 3     [novo, udviklingschef, vild, uge, fler, succes...              2.0
# 4     [nationalregnskab, uden, novo, nordisk, nødven...              0.0
# ...                                                 ...              ...
# 7609            [læg, sæt, pensionspeng, medicinalakti]              0.0
# 7610                  [medicinalbranch, ramt, formkris]             -2.0
# 7611                  [fremstød, dansk, medicin, ægypt]              0.0
# 7612        [fusion, kan, pres, novo, alliancestrategi]              0.0
# 7613               [novo, vinderopskrift, interaktivit]              0.0
#
# [7614 rows x 5 columns]

# %%
#Print the min and max sentiment score to ensure that scale in sensible
min_sentiment = (df_filtered['sentiment_score'].min())
max_sentiment = (df_filtered['sentiment_score'].max())

print("Minimum Sentiment Score:", min_sentiment)
print("Maximum Sentiment Score:", max_sentiment)
# Out:
# Minimum Sentiment Score: -6.0
# Maximum Sentiment Score: 9.0

# %%
# Plotting the distribution of sentiment scores
plt.figure(figsize=(12, 6))
plt.hist(df_filtered['sentiment_score'], bins=50, color='blue', alpha=0.7, label='Sentiment Score Distribution')
plt.title('Distribution of Sentiment Scores')
plt.xlabel('Sentiment Score')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True)
plt.show()

# %%
#Now we ues the group by to get a mean and standard deviation for sentiments for each day
# Group by the 'Date' column and compute the mean and standard deviation for 'sentiment_score'
daily_stats = df_filtered.groupby('Date')['sentiment_score'].agg(['mean', 'std'])
daily_stats
# Out:
#                 mean       std
# Date
# 2000-01-04  0.000000       NaN
# 2000-01-18  0.000000       NaN
# 2000-01-19  0.000000       NaN
# 2000-01-20 -2.000000       NaN
# 2000-01-27  0.000000       NaN
# ...              ...       ...
# 2023-08-08  0.777778  1.986063
# 2023-08-09  2.200000  3.898718
# 2023-08-10  0.333333  0.816497
# 2023-08-11 -2.000000  2.828427
# 2023-08-12  0.000000       NaN
#
# [3331 rows x 2 columns]

# %%
# We now want to find the volume of articles on the given day
# Group by the 'Date' column and count the number of articles for each date
article_counts = df_filtered.groupby('Date').size()

# Add the article counts to the daily_stats dataframe
daily_stats['volume_of_articles'] = article_counts

daily_stats
# Out:
#                 mean       std  volume_of_articles
# Date
# 2000-01-04  0.000000       NaN                   1
# 2000-01-18  0.000000       NaN                   1
# 2000-01-19  0.000000       NaN                   1
# 2000-01-20 -2.000000       NaN                   1
# 2000-01-27  0.000000       NaN                   1
# ...              ...       ...                 ...
# 2023-08-08  0.777778  1.986063                   9
# 2023-08-09  2.200000  3.898718                   5
# 2023-08-10  0.333333  0.816497                   6
# 2023-08-11 -2.000000  2.828427                   2
# 2023-08-12  0.000000       NaN                   1
#
# [3331 rows x 3 columns]
