# %% [markdown]
# ## 2. Scraping Børsen for articles about Novo Nordisk
# This is the second of two largely similar web-scraping files. In this file we scrape the danish financial media platform Børsen for articles regarding Novo Nordisk. We then proceed to process the raw text data extracted and determine the sentiment of the text.

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from webdriver_manager.chrome import ChromeDriverManager
from selenium.common.exceptions import NoSuchElementException
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
from afinn import Afinn

import seaborn as sns
import matplotlib.pyplot as plt
import time
import requests
import os
from bs4 import BeautifulSoup
import pandas as pd
import re
import datetime
import nltk

# %% [markdown]
# #### 1.1 Selenium and Beautiful Soup
# Using selenium we navigate the website to display all relevant articles regarding Novo Nordisk. Given the construction of the website, we create a loop that uses selenium to navigate the page and Beautiful Soup to parse the html and extract titles and publication dates.

# %%
# Set up Selenium with Chrome driver
driver = webdriver.Chrome()
driver.maximize_window()

# Specify the URL
url = "https://borsen.dk/"
driver.get(url)
time.sleep(0.5)

# Accept cookies
cookie = driver.find_element(By.ID, 'acceptButton')
cookie.click()
time.sleep(0.5)

# Click on the search button
search_button = driver.find_element(By.CLASS_NAME, 'icon-search')
search_button.click()
time.sleep(2)

# Search for "Novo Nordisk"
search_input = driver.find_element(By.XPATH, '//input[@type="text"]')
search_input.send_keys('Novo Nordisk')
search_input.send_keys(Keys.RETURN)

# %%
titles = []
dates = []

# Creating the loop
while True:
    # Use Beautiful Soup to parse the current page's HTML
    soup = BeautifulSoup(driver.page_source, "html.parser")

    # Find all titles and dates with the specified class
    title_divs = soup.find_all('div', class_='title mb-3')
    date_divs = soup.find_all('div', class_='gta-condensed date')

    for title_div, date_div in zip(title_divs, date_divs):
        titles.append(title_div.text.strip())
        dates.append(date_div.text.strip())

    # Try to find the "Next" button/link and click it to go to the next page
    try:
        next_button = driver.find_element(By.CSS_SELECTOR, ".col-3.next a")
        next_button.click()
        time.sleep(2)
    except NoSuchElementException:
        break

# Convert the lists to a pandas DataFrame
df = pd.DataFrame({
    'Title': titles,
    'Date': dates
})

# Print the data frame
df
# Out:
#                                                    Title           Date
# 0      Netcompany i stort kursfald: Her er aktierne, ...           9.11
# 1      Regnskabsstorm i C25 udløste store kursudsving...       15. AUG.
# 2      Aktiestatus: Hård medfart til FLS og Jyske Ban...       15. AUG.
# 3      Debat | Der investeres for lidt i Danmark – de...       15. AUG.
# 4      Lille fremgang i dansk økonomi: Novo trækker l...       15. AUG.
# ...                                                  ...            ...
# 26841                                   Centerkontrakter  28. JUN. 1996
# 26842                           Fremgang for Micro Matic  27. JUN. 1996
# 26843                         Øser af sin miljø-erfaring  26. JUN. 1996
# 26844       Danske virksomheder tvinges til nedskæringer  24. JUN. 1996
# 26845                     Vores Øl bliver til Vores Cola  21. JUN. 1996
#
# [26846 rows x 2 columns]

# %% [markdown]
# #### 1.2 GET request
# We use the GET request to scrape medicin.dk to obtain a comprehensive list of Novo Nordisk medicinal products. The list of product names is then added to a keyword list along with manually specified key words. This is later used to filter out irrelevant articles.

# %%
#To filter the articles, we make a list of keywords
#Initially, this list must inclide the names of all Novo Nordisk medical products. These can be obtained as follows: 

# URL to scrape from
url = "https://min.medicin.dk/Adresser/Medicinvirksomheder/126/"

#Defining our logging function
#Disclaimer - this log function is taken directly from the ISDS teaching material
def log(response, logfile, output_path=os.getcwd()):
    if os.path.isfile(logfile):
        log = open(logfile, 'a')
    else:
        log = open(logfile, 'w')
        header = ['timestamp', 'status_code', 'length', 'output_file']
        log.write(';'.join(header) + "\n")

    status_code = response.status_code
    timestamp = time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(time.time()))
    length = len(response.text)

    with open(logfile, 'a') as log:
        log.write(f'{timestamp};{status_code};{length};{output_path}' + "\n")
        
# Send a GET request and log response
logfile = 'log_borsen.csv'
response = requests.get(url, headers={'name': 'Lea Lund Jeppesen', 'e-mail':'snk956@alumni.ku.dk', 'purpose':'University of Copenhagen Social Data Science exam project'})
log(response, logfile)

# Parse the content with BeautifulSoup
soup = BeautifulSoup(response.content, 'lxml')

# Find all product elements
product_elements = soup.find_all('a', class_='glob-search_link')

# Extract the product names from the title attribute
product_names = [product['title'] for product in product_elements]

# Removing special characters and numbers from each product name by using Regular Expressions
product_names_cleaned = [re.sub(r'[^a-zA-Z\s]', '', name) for name in product_names]

# For the 28th element, split it into 2 by space
words = product_names_cleaned[28].split()

# Replace the 28th name with the first word
product_names_cleaned[28] = words[0]

# Insert the second word as the 29th element
product_names_cleaned.insert(30, words[1])

#Print the list
product_names_cleaned
# Out:
# ['Activelle',
#  'Actrapid',
#  'Esperoct',
#  'Estrofem',
#  'Fiasp',
#  'GlucaGen',
#  'Insulatard',
#  'Kliogest',
#  'Levemir',
#  'Mixtard ',
#  'Norditropin',
#  'NovoEight',
#  'Novofem',
#  'NovoMix',
#  'NovoNorm',
#  'NovoRapid',
#  'Novoseven',
#  'NovoThirteen',
#  'Ozempic',
#  'Refixia',
#  'Rybelsus',
#  'Ryzodeg',
#  'Saxenda',
#  'Sogroya',
#  'Tresiba',
#  'Trisekvens',
#  'Vagifem',
#  'Victoza',
#  'Wegovy',
#  'Xultophy',
#  'Flextouch']

# %%
# Define additional keywords, these are determined manually by research on Novo Nordisk medical expertise
keywords = ["Novo", "Nordisk", "insulin", "fedme", "diabetes", "vægttab", "præparat", "overvægt", "slank", "medicin", "pille", "Lars", "Fruergaard", "Jørgensen", "Novo-B", "godkendelse", "NASDAQ", "C25", "hormon", "OMX", "aktie", "forsyning"]

# We then append the product_names_cleaned list to the keywords list
for product in product_names_cleaned:
    keywords.append(product)

print(keywords)
# Out:
# ['Novo', 'Nordisk', 'insulin', 'fedme', 'diabetes', 'vægttab', 'præparat', 'overvægt', 'slank', 'medicin', 'pille', 'Lars', 'Fruergaard', 'Jørgensen', 'Novo-B', 'godkendelse', 'NASDAQ', 'C25', 'hormon', 'OMX', 'aktie', 'forsyning', 'Activelle', 'Actrapid', 'Esperoct', 'Estrofem', 'Fiasp', 'GlucaGen', 'Insulatard', 'Kliogest', 'Levemir', 'Mixtard ', 'Norditropin', 'NovoEight', 'Novofem', 'NovoMix', 'NovoNorm', 'NovoRapid', 'Novoseven', 'NovoThirteen', 'Ozempic', 'Refixia', 'Rybelsus', 'Ryzodeg', 'Saxenda', 'Sogroya', 'Tresiba', 'Trisekvens', 'Vagifem', 'Victoza', 'Wegovy', 'Xultophy', 'Flextouch']

# %% [markdown]
# #### 1.3 Processing of raw text data
# The pandas data frame containing the raw text data is processed using the natural language toolkit to obtain titles that may ber perscribed a sentiment. Furhtermore, the date format of the publication data is altered to correspond to that of yahoo finance data, to allow for merging in the Data_merging.ipynb file.

# %%
# Convert the keywords to lowercase for case-insensitive matching
keywords_lower = [word.lower() for word in keywords]

# Filter the dataframe based on the condition
df_filtered = df[df['Title'].str.lower().str.contains('|'.join(keywords_lower))]

#Delete the first row
df_filtered = df_filtered.iloc[1:]

#Reset index
df_filtered = df_filtered.reset_index(drop=True)

dict_en = {'JAN': 'JAN', 'FEB': 'FEB', 'MAR': 'MAR', 'APR': 'APR', 'MAJ': 'MAY', 'JUN': 'JUN', 'JUL': 'JUL', 'AUG': 'AUG', 'SEP': 'SEP', 'OKT': 'OCT', 'NOV': 'NOV', 'DEC': 'DEC'}

def convert_date(date_string):
    # Remove periods
    date_string = date_string.replace('.', '').strip()

    # Translate month names to English
    for danish, english in dict_en.items():
        date_string = date_string.replace(danish, english)

    # Handle different date formats
    if ":" in date_string:  # It's a time
        return datetime.datetime.now().strftime('%Y-%m-%d')  # Return today's date
    elif len(date_string.split()) == 2:  # Day and month
        current_year = datetime.datetime.now().year
        return datetime.datetime.strptime(date_string + f" {current_year}", '%d %b %Y').strftime('%Y-%m-%d')
    else:  # Full date
        return datetime.datetime.strptime(date_string, '%d %b %Y').strftime('%Y-%m-%d')

# Apply the conversion function to the 'Date' column
df_filtered['Date'] = df_filtered['Date'].apply(convert_date)
df_filtered
# Out:
#                                                    Title        Date
# 0      Regnskabsstorm i C25 udløste store kursudsving...  2023-08-15
# 1      Aktiestatus: Hård medfart til FLS og Jyske Ban...  2023-08-15
# 2      Lille fremgang i dansk økonomi: Novo trækker l...  2023-08-15
# 3      Hårdtprøvet aktie er gået fra overset til optu...  2023-08-14
# 4      Økonom bekymret for produktiviteten: Er vi “bl...  2023-08-14
# ...                                                  ...         ...
# 14531                      Novo trak KFX frem til rekord  1996-08-15
# 14532                     Novo-resultat bliver som lovet  1996-08-14
# 14533                   Danske aktier går som varmt brød  1996-08-08
# 14534         Historien om insulin-krigen i Novo Nordisk  1996-07-18
# 14535    Manden der vil ændre insulinets verdenshistorie  1996-07-18
#
# [14536 rows x 2 columns]

# %%
# Define a processing function that carries out the wanted steps 
def process_text(cell_text): 
    cell_text=cell_text.lower() #Change to lower case
    cell_text=re.sub(r'[^\w\s]','',cell_text) #Remove all characters that are not words or numbers
    cell_text=cell_text.split() #Split at whitespace with the split() method (i.e., tokenization)
    return cell_text

# Apply the processing function
df_filtered['Title'] = df_filtered['Title'].apply(process_text)

# Print the data frame
df_filtered
# Out:
#                                                    Title        Date
# 0      [regnskabsstorm, i, c25, udløste, store, kursu...  2023-08-15
# 1      [aktiestatus, hård, medfart, til, fls, og, jys...  2023-08-15
# 2      [lille, fremgang, i, dansk, økonomi, novo, træ...  2023-08-15
# 3      [hårdtprøvet, aktie, er, gået, fra, overset, t...  2023-08-14
# 4      [økonom, bekymret, for, produktiviteten, er, v...  2023-08-14
# ...                                                  ...         ...
# 14531               [novo, trak, kfx, frem, til, rekord]  1996-08-15
# 14532                 [novoresultat, bliver, som, lovet]  1996-08-14
# 14533            [danske, aktier, går, som, varmt, brød]  1996-08-08
# 14534   [historien, om, insulinkrigen, i, novo, nordisk]  1996-07-18
# 14535  [manden, der, vil, ændre, insulinets, verdensh...  1996-07-18
#
# [14536 rows x 2 columns]

# %%
# Convert the 'Date' column to datetime format
df_filtered['Date'] = pd.to_datetime(df_filtered['Date'])

# Reset the index after filtering
df_filtered = df_filtered.reset_index(drop=True)

# Print the data frame
df_filtered
# Out:
#                                                    Title       Date
# 0      [regnskabsstorm, i, c25, udløste, store, kursu... 2023-08-15
# 1      [aktiestatus, hård, medfart, til, fls, og, jys... 2023-08-15
# 2      [lille, fremgang, i, dansk, økonomi, novo, træ... 2023-08-15
# 3      [hårdtprøvet, aktie, er, gået, fra, overset, t... 2023-08-14
# 4      [økonom, bekymret, for, produktiviteten, er, v... 2023-08-14
# ...                                                  ...        ...
# 14531               [novo, trak, kfx, frem, til, rekord] 1996-08-15
# 14532                 [novoresultat, bliver, som, lovet] 1996-08-14
# 14533            [danske, aktier, går, som, varmt, brød] 1996-08-08
# 14534   [historien, om, insulinkrigen, i, novo, nordisk] 1996-07-18
# 14535  [manden, der, vil, ændre, insulinets, verdensh... 1996-07-18
#
# [14536 rows x 2 columns]

# %%
#We want to remove stopwords
nltk.download('stopwords', quiet=True)
stop = stopwords.words('danish')

#Remove stopwards
df_filtered['title_nostop'] = df_filtered['Title'].apply(lambda title: [i for i in title if i not in stop])

#We ensure that some stopwords were actually removed
print(len(df_filtered['Title'].iloc[0]), len(df_filtered['title_nostop'].iloc[0]))

#Print the data_frame
df_filtered
# Out:
# 12 8
#                                                    Title       Date  \
# 0      [regnskabsstorm, i, c25, udløste, store, kursu... 2023-08-15
# 1      [aktiestatus, hård, medfart, til, fls, og, jys... 2023-08-15
# 2      [lille, fremgang, i, dansk, økonomi, novo, træ... 2023-08-15
# 3      [hårdtprøvet, aktie, er, gået, fra, overset, t... 2023-08-14
# 4      [økonom, bekymret, for, produktiviteten, er, v... 2023-08-14
# ...                                                  ...        ...
# 14531               [novo, trak, kfx, frem, til, rekord] 1996-08-15
# 14532                 [novoresultat, bliver, som, lovet] 1996-08-14
# 14533            [danske, aktier, går, som, varmt, brød] 1996-08-08
# 14534   [historien, om, insulinkrigen, i, novo, nordisk] 1996-07-18
# 14535  [manden, der, vil, ændre, insulinets, verdensh... 1996-07-18
#
#                                             title_nostop
# 0      [regnskabsstorm, c25, udløste, store, kursudsv...
# 1      [aktiestatus, hård, medfart, fls, jyske, bank,...
# 2      [lille, fremgang, dansk, økonomi, novo, trække...
# 3      [hårdtprøvet, aktie, gået, overset, optur, ste...
# 4      [økonom, bekymret, produktiviteten, blevet, lu...
# ...                                                  ...
# 14531                    [novo, trak, kfx, frem, rekord]
# 14532                              [novoresultat, lovet]
# 14533                 [danske, aktier, går, varmt, brød]
# 14534          [historien, insulinkrigen, novo, nordisk]
# 14535       [manden, ændre, insulinets, verdenshistorie]
#
# [14536 rows x 3 columns]

# %%
nltk.download('omw-1.4', quiet=True)
nltk.download('wordnet', quiet=True)

# Initialize the Danish SnowballStemmer
stemmer = SnowballStemmer("danish")

# Define the stemming function
def stem_text(tokens):
    return [stemmer.stem(token) for token in tokens]

# Apply the function to each row of the 'title_nostop' column
df_filtered['title_stemmed'] = df_filtered['title_nostop'].apply(stem_text)

#We check to see of the stemmed words make sense
df_filtered
#From this we conclude that the stemmed danish words are often incorrect. Thus, we continue with determining the sentiment of the nostop column.
# Out:
#                                                    Title       Date  \
# 0      [regnskabsstorm, i, c25, udløste, store, kursu... 2023-08-15
# 1      [aktiestatus, hård, medfart, til, fls, og, jys... 2023-08-15
# 2      [lille, fremgang, i, dansk, økonomi, novo, træ... 2023-08-15
# 3      [hårdtprøvet, aktie, er, gået, fra, overset, t... 2023-08-14
# 4      [økonom, bekymret, for, produktiviteten, er, v... 2023-08-14
# ...                                                  ...        ...
# 14531               [novo, trak, kfx, frem, til, rekord] 1996-08-15
# 14532                 [novoresultat, bliver, som, lovet] 1996-08-14
# 14533            [danske, aktier, går, som, varmt, brød] 1996-08-08
# 14534   [historien, om, insulinkrigen, i, novo, nordisk] 1996-07-18
# 14535  [manden, der, vil, ændre, insulinets, verdensh... 1996-07-18
#
#                                             title_nostop  \
# 0      [regnskabsstorm, c25, udløste, store, kursudsv...
# 1      [aktiestatus, hård, medfart, fls, jyske, bank,...
# 2      [lille, fremgang, dansk, økonomi, novo, trække...
# 3      [hårdtprøvet, aktie, gået, overset, optur, ste...
# 4      [økonom, bekymret, produktiviteten, blevet, lu...
# ...                                                  ...
# 14531                    [novo, trak, kfx, frem, rekord]
# 14532                              [novoresultat, lovet]
# 14533                 [danske, aktier, går, varmt, brød]
# 14534          [historien, insulinkrigen, novo, nordisk]
# 14535       [manden, ændre, insulinets, verdenshistorie]
#
#                                            title_stemmed
# 0      [regnskabsstorm, c25, udløst, stor, kursudsvin...
# 1      [aktiestatus, hård, medfart, fls, jysk, bank, ...
# 2       [lil, fremgang, dansk, økonomi, novo, træk, læs]
# 3      [hårdtprøv, akti, gået, overs, optur, steg, 40...
# 4      [økonom, bekymr, produktivitet, blev, lul, søv...
# ...                                                  ...
# 14531                    [novo, trak, kfx, frem, rekord]
# 14532                                [novoresultat, lov]
# 14533                    [dansk, akti, går, varmt, brød]
# 14534                [histori, insulinkr, novo, nordisk]
# 14535              [mand, ændr, insulin, verdenshistori]
#
# [14536 rows x 4 columns]

# %% [markdown]
# #### 1.4 Sentiments
# Using the AFINN lexicon, we perscribe a sentiment score to each to the titles.

# %%
#We determne the sentiment using a predefined lexicon
# Initialize the Afinn object for Danish
afn = Afinn(language='da', emoticons=True)

# Convert the list of words in 'title_nostop' to a single string and then apply the AFINN sentiment scoring function
df_filtered['sentiment_score'] = df_filtered['title_nostop'].apply(lambda title_list: afn.score(' '.join(title_list)))

#Display the Data Frame
df_filtered
# Out:
#                                                    Title       Date  \
# 0      [regnskabsstorm, i, c25, udløste, store, kursu... 2023-08-15
# 1      [aktiestatus, hård, medfart, til, fls, og, jys... 2023-08-15
# 2      [lille, fremgang, i, dansk, økonomi, novo, træ... 2023-08-15
# 3      [hårdtprøvet, aktie, er, gået, fra, overset, t... 2023-08-14
# 4      [økonom, bekymret, for, produktiviteten, er, v... 2023-08-14
# ...                                                  ...        ...
# 14531               [novo, trak, kfx, frem, til, rekord] 1996-08-15
# 14532                 [novoresultat, bliver, som, lovet] 1996-08-14
# 14533            [danske, aktier, går, som, varmt, brød] 1996-08-08
# 14534   [historien, om, insulinkrigen, i, novo, nordisk] 1996-07-18
# 14535  [manden, der, vil, ændre, insulinets, verdensh... 1996-07-18
#
#                                             title_nostop  \
# 0      [regnskabsstorm, c25, udløste, store, kursudsv...
# 1      [aktiestatus, hård, medfart, fls, jyske, bank,...
# 2      [lille, fremgang, dansk, økonomi, novo, trække...
# 3      [hårdtprøvet, aktie, gået, overset, optur, ste...
# 4      [økonom, bekymret, produktiviteten, blevet, lu...
# ...                                                  ...
# 14531                    [novo, trak, kfx, frem, rekord]
# 14532                              [novoresultat, lovet]
# 14533                 [danske, aktier, går, varmt, brød]
# 14534          [historien, insulinkrigen, novo, nordisk]
# 14535       [manden, ændre, insulinets, verdenshistorie]
#
#                                            title_stemmed  sentiment_score
# 0      [regnskabsstorm, c25, udløst, stor, kursudsvin...              0.0
# 1      [aktiestatus, hård, medfart, fls, jysk, bank, ...              2.0
# 2       [lil, fremgang, dansk, økonomi, novo, træk, læs]              0.0
# 3      [hårdtprøv, akti, gået, overs, optur, steg, 40...             -2.0
# 4      [økonom, bekymr, produktivitet, blev, lul, søv...              2.0
# ...                                                  ...              ...
# 14531                    [novo, trak, kfx, frem, rekord]              0.0
# 14532                                [novoresultat, lov]              1.0
# 14533                    [dansk, akti, går, varmt, brød]             -1.0
# 14534                [histori, insulinkr, novo, nordisk]              0.0
# 14535              [mand, ændr, insulin, verdenshistori]              0.0
#
# [14536 rows x 5 columns]

# %%
#Print the min and max sentiment score to ensure that scale in sensible
min_sentiment = (df_filtered['sentiment_score'].min())
max_sentiment = (df_filtered['sentiment_score'].max())

print("Minimum Sentiment Score:", min_sentiment)
print("Maximum Sentiment Score:", max_sentiment)
# Out:
# Minimum Sentiment Score: -7.0
# Maximum Sentiment Score: 9.0

# %%
# Plotting the distribution of sentiment scores
blue_palette = sns.color_palette("Blues_d", 2)

plt.figure(figsize=(12, 6))
plt.hist(df_filtered['sentiment_score'], bins=50, color=blue_palette[1], alpha=0.7, label='Sentiment Score Distribution')
plt.title('Distribution of Sentiment Scores Borsen', fontsize=16, fontweight='bold', fontname='DejaVu Sans')
plt.xlabel('Sentiment Score', fontsize=12, fontname='DejaVu Sans')
plt.ylabel('Frequency', fontsize=12, fontname='DejaVu Sans')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
sns.despine()

plt.tight_layout()
plt.savefig('Sentiment_Score_Distribution_borsen.png')
plt.show()

# %%
#Rename the dataframe
daily_stats_borsen=df_filtered

#Now we want to convert the dataframe daily_stats_borsen to a csv file
daily_stats_borsen.to_csv('./CSV/daily_stats_borsen.csv', index=False)
